# %% [markdown]
# # BinarySearchTree
# * 一開始的個人理解
#   * 最主要條件:永遠保持左邊放小，右邊放大
#   * Insert
#     * 如果比Parent小放左邊，比Parent大放右邊
#   * Delete
#     * 沒有小孩可以直接刪
#     * 需考慮到的狀況
#       * 1.只有左有小孩
#       * 2.只有右有小孩
#       * 3.左邊跟右邊都有小孩
#   * Search
#     * 回傳離Root最近的
#   * Modify
# * 參考資料:
#   * Insert參考資料:
#     * https://gist.github.com/jakemmarsh/8273963
#     * http://alrightchiu.github.io/SecondRound/binary-search-tree-searchsou-xun-zi-liao-insertxin-zeng-zi-liao.html
#   * Delete參考資料:
#     * https://www.youtube.com/watch?v=LSju119w8BE
#     * https://www.youtube.com/watch?v=gcULXE7ViZw
#     * https://www.youtube.com/watch?v=Zaf8EOVa72I
#     * http://alrightchiu.github.io/SecondRound/binary-search-tree-sortpai-xu-deleteshan-chu-zi-liao.html
#     * https://buptldy.github.io/2016/05/09/2016-05-09-Python%20BST/
#   * Search參考資料:
#     * http://alrightchiu.github.io/SecondRound/binary-search-tree-searchsou-xun-zi-liao-insertxin-zeng-zi-liao.html
#   * Modify參考資料:
#   * 共同參考資料:
#     * https://www.laurentluce.com/posts/binary-search-tree-library-in-python/
#     * https://www.youtube.com/watch?v=YlgPi75hIBc
#     * https://zh.wikipedia.org/wiki/%E4%BA%8C%E5%85%83%E6%90%9C%E5%B0%8B%E6%A8%B9

# %% [markdown]
# ## BST原理
# * 比parent小放在left，比parent大放在右邊
# * 最左邊的leaf node會是最小的，最右邊的leaf node會是最大的
# * Search時有重複的數會回傳離root最近的
# * Modify更改時有重複的數都要一起改
# * Delete有分三種狀況，依照子節點的數量及方向來區分，還有取代的方式，詳見Delete部分

# %%
from IPython.display import Image
from IPython.core.display import HTML

# %% [markdown]
# ## Insert流程圖

# %%
Image(filename = "D:\三上-資料結構與演算法\S__47276034.jpg", width=550, height=500)

# %% [markdown]
# ## Delete流程圖

# %%
Image(filename = "D:\三上-資料結構與演算法\S__47325186.jpg", width=550, height=500)

# %%
Image(filename = "D:\三上-資料結構與演算法\S__47349768.jpg", width=550, height=500)

# %% [markdown]
# ## Search流程圖

# %%
Image(filename = "D:\三上-資料結構與演算法\S__47276036.jpg", width=550, height=500)

# %% [markdown]
# ## Modify流程圖

# %%
Image(filename = "D:\三上-資料結構與演算法\S__47349769.jpg", width=550, height=500)

# %%
class TreeNode(object):
    def __init__(self, x):
        self.val = x
        self.left = None
        self.right = None

# %%
def insert(self, root, value):
    if self.root:
        if self.value <= self.root:
            if self.left == None:
                self.left == TreeNode(value)
            else:
                self.left.insert(value)
        elif self.value > self.root:
            if self.right == None:
                self.right == TreeNode(value)
            else:
                self.right.insert(value)
    else:
        self.root == value

# %%
class TreeNode(object):
    def __init__(self, x):
        self.val = x
        self.left = None
        self.right = None

class Solution(object):
    def insert(self, root, val):
        self.insert(root, val)
        self.root = root
        self.val = val
        if root == None:
            root == TreeNode(val)
        elif root != None:
            if val <= root:
                if root.left == None:
                    root.left == TreeNode(val)
                else:
                    self.insert(root.left, val)
            elif val > root:
                if root.right == None:
                    root.right == TreeNode(val)
                else:
                    self.insert(root.right, val)
        return True

# %%
root = TreeNode(5)
root.left = TreeNode(3)
root.left.left = TreeNode(3)
root.left.left.left = TreeNode(-5)
root.right = TreeNode(8)
root.right.left = TreeNode(7)
root.right.right = TreeNode(10)
root.right.left.left = TreeNode(6) 
print(Solution().insert(root,4) == root.left.right)
# Out:
# ---------------------------------------------------------------------------
# RecursionError                            Traceback (most recent call last)
# <ipython-input-35-8d09c5b1ca98> in <module>
#       7 root.right.right = TreeNode(10)
#       8 root.right.left.left = TreeNode(6)
# ----> 9 print(Solution().insert(root,4) == root.left.right)
#
# <ipython-input-34-df813a32afdf> in insert(self, root, val)
#       7 class Solution(object):
#       8     def insert(self, root, val):
# ----> 9         self.insert(root, val)
#      10         self.root = root
#      11         self.val = val
#
# ... last 1 frames repeated, from the frame below ...
#
# <ipython-input-34-df813a32afdf> in insert(self, root, val)
#       7 class Solution(object):
#       8     def insert(self, root, val):
# ----> 9         self.insert(root, val)
#      10         self.root = root
#      11         self.val = val
#
# RecursionError: maximum recursion depth exceeded

# %% [markdown]
# 第九行進入了無限迴圈了
#
# 繼續努力尋找方法

# %%
class TreeNode(object):
    def __init__(self, x):
        self.val = x
        self.left = None
        self.right = None
class Solution:
    def insert(self, root, val):
        self.root = root
        self.val = val
        if root == None:
            root = TreeNode(val)
        elif val <= root.val:
            self.insert(root.left, val)
        else:
            self.insert(root.right, val)
        return root

# %%
root = TreeNode(5)
root.left = TreeNode(3)
root.left.left = TreeNode(3)
root.left.left.left = TreeNode(-5)
root.right = TreeNode(8)
root.right.left = TreeNode(7)
root.right.right = TreeNode(10)
root.right.left.left = TreeNode(6) 
print(Solution().insert(root,4) == root.left.right)
# Out:
# False

# %% [markdown]
# 用測值試試看

# %%
import copy

# %%
root1 = copy.deepcopy(root)

# %%
print(Solution().insert(root1,4)==root1.left.right)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-56-cd079337fa81> in <module>
# ----> 1 print(Solution().insert(root1,4)==root1.left.right)
#
# AttributeError: 'Solution' object has no attribute 'insert'

# %% [markdown]
# 以下的程式碼原本跑出來會是False，要再次檢查哪裡邏輯有錯誤

# %%
class TreeNode(object):
    def __init__(self, x):
        self.val = x
        self.left = None
        self.right = None
class Solution:
    def insert(self, root, val):
        self.root = root
        self.val = val
        if root == None:
            root = TreeNode(val)
        elif val <= root.val:
            if root.left != None:
                root = root.left
            else:
                root.left = TreeNode(val)
            if root.right != None:
                root = root.right
            else:
                root.right = TreeNode(val)

# %%
root = TreeNode(5)
root.left = TreeNode(3)
root.left.left = TreeNode(3)
root.left.left.left = TreeNode(-5)
root.right = TreeNode(8)
root.right.left = TreeNode(7)
root.right.right = TreeNode(10)
root.right.left.left = TreeNode(6) 
print(Solution().insert(root,4) == root.left.right)
# Out:
# False

# %% [markdown]
# 這邊的邏輯犯了一個小錯誤哈哈，應該改成以下程式碼

# %%
class TreeNode(object):
    def __init__(self, x):
        self.val = x
        self.left = None
        self.right = None
class Solution:
    def insert(self, root, val):
        self.root = root
        self.val = val
        if root == None:
            root = TreeNode(val)
        elif val <= root.val:
            if root.left != None:
                root = root.left
                return root
            else:
                root.left = TreeNode(val)
                return root.left
            if root.right != None:
                root = root.right
                return root
            else:
                root.right = TreeNode(val)
                return root.right

# %%
root = TreeNode(5)
root.left = TreeNode(3)
root.left.left = TreeNode(3)
root.left.left.left = TreeNode(-5)
root.right = TreeNode(8)
root.right.left = TreeNode(7)
root.right.right = TreeNode(10)
root.right.left.left = TreeNode(6) 
print(Solution().insert(root,4) == root.left.right)
# Out:
# False

# %%
class TreeNode(object):
    def __init__(self, x):
        self.val = x
        self.left = None
        self.right = None
class Solution:
    def insert(self, root, val):
        self.root = root
        self.val = val
        if root == None: #如果root原本沒有東西的話，新的節點即為root
            root = TreeNode(val)
        elif val <= root.val: #如果val的值小於root的值，放左邊，並討論左邊如果沒有值以及有值的時候
            if root.left != None:
                self.insert(root.left, val)
            else:
                root.left = TreeNode(val)
                root.left
        elif val > root.val: #如果val的值大於root的值，放右邊，並討論左邊如果沒有值以及有值的時候
            if root.right != None:
                self.insert(root.right, val)
            else:
                root.right = TreeNode(val)
                root.right

# %%
root = TreeNode(5)
root.left = TreeNode(3)
root.left.left = TreeNode(3)
root.left.left.left = TreeNode(-5)
root.right = TreeNode(8)
root.right.left = TreeNode(7)
root.right.right = TreeNode(10)
root.right.left.left = TreeNode(6) 
print(Solution().insert(root,4) == root.left.right)
# Out:
# False

# %% [markdown]
# 結果還是有問題@@
#
# 以下是繼續修改後，從False變成True的正確版本，也是最終版的insert!!!!

# %%
class TreeNode(object):
    def __init__(self, x):
        self.val = x
        self.left = None
        self.right = None
class Solution:
    def insert(self, root, val):
        self.root = root
        self.val = val
        if root == None: #如果root原本沒有東西的話，新的節點即為root
            root = TreeNode(val)
        elif val <= root.val: #如果val的值小於root的值，放左邊，並討論左邊如果沒有值以及有值的時候
            if root.left != None:
                return self.insert(root.left, val)
            else:
                root.left = TreeNode(val)
                return root.left
        elif val > root.val: #如果val的值大於root的值，放右邊，並討論左邊如果沒有值以及有值的時候
            if root.right != None:
                return self.insert(root.right, val)
            else:
                root.right = TreeNode(val)
                return root.right

# %%
root = TreeNode(5)
root.left = TreeNode(3)
root.left.left = TreeNode(3)
root.left.left.left = TreeNode(-5)
root.right = TreeNode(8)
root.right.left = TreeNode(7)
root.right.right = TreeNode(10)
root.right.left.left = TreeNode(6) 
print(Solution().insert(root,4) == root.left.right)
print(Solution().insert(root,-6) == root.left.left.left.left)
print(Solution().insert(root,12) == root.right.right.right)
print(Solution().insert(root,9) == root.right.right.left)
# Out:
# True
# True
# True
# True

# %% [markdown]
# 終於對了!!!!!!!!!!!!!!!!要加上return回傳數值
#
# 這邊我試試看insert較多數來驗證，提高正確性

# %%
class TreeNode(object):
    def __init__(self, x):
        self.val = x
        self.left = None
        self.right = None
        
class Solution(object):
    def search(self, root, target):
        self.root = root
        self.target = target
        if not root:
            return None
        elif root == target:
            return root
        elif root < target:
            return self.search(root.right, target)
        elif root > target:
            return self.search(root.left, target)

# %%
root = TreeNode(5)
root.left = TreeNode(3)
root.left.left = TreeNode(3)
root.left.left.left = TreeNode(-5)
root.right = TreeNode(8)
root.right.left = TreeNode(7)
root.right.right = TreeNode(10)
root.right.left.left = TreeNode(6)
print(Solution().search(root,10)==root.right.right)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-47-a538c0a4703f> in <module>
#       7 root.right.right = TreeNode(10)
#       8 root.right.left.left = TreeNode(6)
# ----> 9 print(Solution().search(root,10)==root.right.right)
#
# <ipython-input-46-9bf26682f726> in search(self, root, target)
#      13         elif root == target:
#      14             return root
# ---> 15         elif root < target:
#      16             return self.search(root.right, target)
#      17         elif root > target:
#
# TypeError: '<' not supported between instances of 'TreeNode' and 'int'

# %% [markdown]
# root沒辦法直接和target比較，要呼叫root的值，所以root要加上.val才能比較
#
# 因此改成

# %%
class TreeNode(object):
    def __init__(self, x):
        self.val = x
        self.left = None
        self.right = None
        
class Solution(object):
    def search(self, root, target):
        self.root = root
        self.target = target
        if not root: #如果root不存在，表示search不到，直接回傳None
            return None
        elif root.val == target: #如果root與target相等，search可直接回傳root值
            return root
        elif root.val < target: #如果root比target小(target比root大)，要繼續往右search
            return self.search(root.right, target)
        elif root.val > target: #如果root比target大(target比root小)，要繼續往左search
            return self.search(root.left, target)

# %%
root = TreeNode(5)
root.left = TreeNode(3)
root.left.left = TreeNode(3)
root.left.left.left = TreeNode(-5)
root.right = TreeNode(8)
root.right.left = TreeNode(7)
root.right.right = TreeNode(10)
root.right.left.left = TreeNode(6)
print(Solution().search(root,10)==root.right.right)
print(Solution().search(root,3)==root.left)
print(Solution().search(root,3)==root.left.left)
print(Solution().search(root,-5)==root.left.left.left)
print(Solution().search(root,8)==root.right)
print(Solution().search(root,7)==root.right.left)
print(Solution().search(root,6)==root.right.left.left)
# Out:
# True
# True
# False
# True
# True
# True
# True

# %% [markdown]
# 這邊也一樣試驗看看所有的值，確保每個位子都是對的
#
# 關於第三個False是因為在search裡，如果有重複的值，會回傳離root最近的值

# %% [markdown]
# search完成了!!!先把insert和search合併在一起試試看

# %%
class TreeNode(object):
    def __init__(self, x):
        self.val = x
        self.left = None
        self.right = None
class Solution(object):
    def insert(self, root, val):
        self.root = root
        self.val = val
        if root == None: #如果root原本沒有東西的話，新的節點即為root
            root = TreeNode(val)
        elif val <= root.val: #如果val的值小於root的值，放左邊，並討論左邊如果沒有值以及有值的時候
            if root.left != None:
                return self.insert(root.left, val)
            else:
                root.left = TreeNode(val)
                return root.left
        elif val > root.val: #如果val的值大於root的值，放右邊，並討論左邊如果沒有值以及有值的時候
            if root.right != None:
                return self.insert(root.right, val)
            else:
                root.right = TreeNode(val)
                return root.right
    def search(self, root, target):
        self.root = root
        self.target = target
        if not root: #如果root不存在，表示search不到，直接回傳None
            return None
        elif root.val == target: #如果root與target相等，search可直接回傳root值
            return root
        elif root.val < target: #如果root比target小(target比root大)，要繼續往右search
            return self.search(root.right, target)
        elif root.val > target: #如果root比target大(target比root小)，要繼續往左search
            return self.search(root.left, target)

# %%
root = TreeNode(5)
root.left = TreeNode(3)
root.left.left = TreeNode(3)
root.left.left.left = TreeNode(-5)
root.right = TreeNode(8)
root.right.left = TreeNode(7)
root.right.right = TreeNode(10)
root.right.left.left = TreeNode(6) 
print(Solution().insert(root,4) == root.left.right)
print(Solution().search(root,10)==root.right.right)
# Out:
# True
# True

# %% [markdown]
# Delete參考了網路上的code

# %%
class TreeNode(object):
    def __init__(self, x):
        self.val = x
        self.left = None
        self.right = None
class Solution(object):
    def find(self, parent, node, key):
        if node:
            if node.val==key:
                return (parent, node)
            elif node.val<key:
                return self.find(node, node.right, key)
            else:
                return self.find(node, node.left, key)
        return None,None
    
    def del_min(self, node):
        if node.left==None:
            return node.val, node.right
        val, node.left = self.del_min(node.left)
        return val, node
        
    def delete(self, root: TreeNode, key: int) -> TreeNode:
        parent, node = self.find(None, root, key)
        if node==None: return root
        if node.left==None or node.right==None:
            if parent==None:
                return node.left if node.left else node.right
            else:
                if parent.left==node:
                    parent.left = node.left if node.left else node.right
                else:
                    parent.right = node.left if node.left else node.right
        else:
            right_min, node.right = self.del_min(node.right)
            node.val = right_min
            if parent==None: return node
        return root

# %%
roots = TreeNode(5)
roots.left = TreeNode(3)
roots.left.left = TreeNode(3)
roots.left.left.left = TreeNode(-5)
roots.right = TreeNode(8)
roots.right.left = TreeNode(7)
roots.right.right = TreeNode(10)
roots.right.left.left = TreeNode(6) 
Solution().delete(roots,3)
print(roots.val==5 and roots.left.right==None and roots.left.val==-5 and roots.left.left==None)
# Out:
# False

# %% [markdown]
# 這邊是False，所以我想用print來看每一個數的數值
#
# 這樣就能看出來哪裡有錯誤

# %%
roots = TreeNode(5)
roots.left = TreeNode(3)
roots.left.left = TreeNode(3)
roots.left.left.left = TreeNode(-5)
roots.right = TreeNode(8)
roots.right.left = TreeNode(7)
roots.right.right = TreeNode(10)
roots.right.left.left = TreeNode(6) 
Solution().delete(roots,3)
print(roots.val==5 and roots.left.right==None and roots.left.val==-5 and roots.left.left==None)
print(roots.val)
print(roots.left.right)
print(roots.left.val)
print(roots.left.left)
# Out:
# False
# 5
# None
# 3
# ...

# %% [markdown]
# root.left.left應該會有值，所以沒辦法print出來，加上val來看裡面的值

# %%
roots = TreeNode(5)
roots.left = TreeNode(3)
roots.left.left = TreeNode(3)
roots.left.left.left = TreeNode(-5)
roots.right = TreeNode(8)
roots.right.left = TreeNode(7)
roots.right.right = TreeNode(10)
roots.right.left.left = TreeNode(6) 
Solution().delete(roots,3)
print(roots.val==5 and roots.left.right==None and roots.left.val==-5 and roots.left.left==None)
print(roots.val)
print(roots.left.right)
print(roots.left.val)
print(roots.left.left.val)
# Out:
# False
# 5
# None
# 3
# -5

# %% [markdown]
# 這邊就能看出來，我原本要刪掉3的值，但是只刪到第一個3，第二個3沒有被刪到
#
# 試試看用while刪到沒有這個數為止

# %%
class TreeNode(object):
    def __init__(self, x):
        self.val = x
        self.left = None
        self.right = None

class Solution(object):
    def find(self, parent, node, key):
        if node:
            if node.val==key:
                return (parent, node)
            elif node.val<key:
                return self.find(node, node.right, key)
            else:
                return self.find(node, node.left, key)
        return None,None
    
    def del_min(self, node):
        if node.left==None:
            return node.val, node.right
        val, node.left = self.del_min(node.left)
        return val, node
        
    def delete(self, root, target):
        while self.find(None,None)!=(None,None):
            parent, node = self.search(None, root, target)
            if node==None: return root
            if node.left==None or node.right==None:
                if parent==None:
                    return node.left if node.left else node.right
                else:
                    if parent.left==node:
                        parent.left = node.left if node.left else node.right
                    else:
                        parent.right = node.left if node.left else node.right
            else:
                right_min, node.right = self.del_min(node.right)
                node.val = right_min
                if parent==None: return node
            return root

# %%
roots = TreeNode(5)
roots.left = TreeNode(3)
roots.left.left = TreeNode(3)
roots.left.left.left = TreeNode(-5)
roots.right = TreeNode(8)
roots.right.left = TreeNode(7)
roots.right.right = TreeNode(10)
roots.right.left.left = TreeNode(6) 
Solution().delete(roots,3)
print(roots.val==5 and roots.left.right==None and roots.left.val==-5 and roots.left.left==None)
print(roots.val)
print(roots.left.right)
print(roots.left.val)
print(roots.left.left.val)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-27-01fdd7dcbc0f> in <module>
#       7 roots.right.right = TreeNode(10)
#       8 roots.right.left.left = TreeNode(6)
# ----> 9 Solution().delete(roots,3)
#      10 print(roots.val==5 and roots.left.right==None and roots.left.val==-5 and roots.left.left==None)
#      11 print(roots.val)
#
# <ipython-input-26-3221999f4806> in delete(self, root, target)
#      17
#      18     def delete(self, root, target):
# ---> 19         while self.find(None,None)!=(None,None):
#      20             parent, node = self.search(None, root, target)
#      21             if node==None: return root
#
# TypeError: find() missing 1 required positional argument: 'key'

# %% [markdown]
# 不小心寫錯了，find少一個參數，應改成(None,None,target)

# %%
class TreeNode(object):
    def __init__(self, x):
        self.val = x
        self.left = None
        self.right = None

class Solution(object):
    def find(self, parent, node, key):
        if node:
            if node.val==key:
                return (parent, node)
            elif node.val<key:
                return self.find(node, node.right, key)
            else:
                return self.find(node, node.left, key)
        return None,None
    
    def del_min(self, node):
        if node.left==None:
            return node.val, node.right
        val, node.left = self.del_min(node.left)
        return val, node
        
    def delete(self, root, target):
        while self.find(None,None,target)!=(None,None):
            parent, node = self.find(None, root, target)
            if node==None: return root
            if node.left==None or node.right==None:
                if parent==None:
                    return node.left if node.left else node.right
                else:
                    if parent.left==node:
                        parent.left = node.left if node.left else node.right
                    else:
                        parent.right = node.left if node.left else node.right
            else:
                right_min, node.right = self.del_min(node.right)
                node.val = right_min
                if parent==None: return node
            return root

# %%
roots = TreeNode(5)
roots.left = TreeNode(3)
roots.left.left = TreeNode(3)
roots.left.left.left = TreeNode(-5)
roots.right = TreeNode(8)
roots.right.left = TreeNode(7)
roots.right.right = TreeNode(10)
roots.right.left.left = TreeNode(6) 
Solution().delete(roots,3)
print(roots.val==5 and roots.left.right==None and roots.left.val==-5 and roots.left.left==None)
print(roots.val)
print(roots.left.right)
print(roots.left.val)
print(roots.left.left.val)
# Out:
# False
# 5
# None
# 3
# 3

# %% [markdown]
# 怎麼還是一樣...改了一下delete function裡的條件式

# %%
class TreeNode(object):
    def __init__(self, x):
        self.val = x
        self.left = None
        self.right = None
        
class Solution(object):
    def find(self, parent, root, target): #find放了3個參數
        if root == None: #如果root是空的，那就會find不到，找不到直接回傳None
            return None, None
        elif root != None: #如果root不是空的，分成幾種情況
            if root.val == target: #如果root等於要找的target
                return (parent, root) #回傳parent和root本身，因為有設三個變數，須把parent也return
            elif root.val > target: #如果root大於target
                return self.find(root, root.left, target) #把root當成parent，並繼續往左邊找
            elif root.val < target: #如果root小於target
                return self.find(root, root.right, target) #跟大於一樣，只是如果是小於，要往右邊找
    
    def del_min(self, node): #刪掉最小值
        if node.left==None: #如果進來節點的左邊沒有值，代表沒有最小值
            return node.val, node.right #直接回傳此節點值和右邊較大的點
        else: #剩下是如果進來節點的左邊有值
            val, node.left = self.del_min(node.left) #就看node.left.left是否有值，再跑del_min
            #會變成如果node.left.left空就回傳node.left.val,node.left.right
            return val, node
    
    def delete(self, root, target):
        while self.find(None, root, target) != (None, None):
            parent, node = self.find(None, root, target) #先用find找到node還有其parent
            if node.left == None or node.right == None: #有左或右一個child
                if parent != None: #如果節點也有parent
                    if parent.left == node: #如果此節點在parent的左邊
                        if node.left:
                            parent.left = node.left
                        if node.right:
                            parent.left = node.right
                        # 如果節點存在的子節點是在左，那就把左子節點接到parent的左邊
                        # 反之，存在的子節點是右，也是直接接到parent的左邊，那麼原本的node就會被取代掉
                    elif parent.right == node: #如果此節點在parent的右邊
                        if node.left:
                            parent.right = node.left
                        if node.right:
                            parent.right = node.right
                        #與上面相同道理，只是把node設在parent的右子節點
            else:
                right_min, node.right = self.del_min(node.right) #要找右邊subtree最小的取代
                node.val = right_min

# %%
roots = TreeNode(5)
roots.left = TreeNode(3)
roots.left.left = TreeNode(3)
roots.left.left.left = TreeNode(-5)
roots.right = TreeNode(8)
roots.right.left = TreeNode(7)
roots.right.right = TreeNode(10)
roots.right.left.left = TreeNode(6) 
Solution().delete(roots,3)
print(roots.val==5 and roots.left.right==None and roots.left.val==-5 and roots.left.left==None)
print(roots.val)
print(roots.left.right)
print(roots.left.val)
print(roots.left.left)
# Out:
# True
# 5
# None
# -5
# None

# %% [markdown]
# 拿其他測值試試看

# %%
roots = TreeNode(5)
roots.left = TreeNode(3)
roots.left.left = TreeNode(3)
roots.left.left.left = TreeNode(-5)
roots.right = TreeNode(8)
roots.right.left = TreeNode(7)
roots.right.right = TreeNode(10)
roots.right.left.left = TreeNode(6) 
Solution().delete(roots,6)
print(roots.val==5 and roots.left.right==None and roots.left.val==3 and roots.right.left.left==None)
print(roots.val)
print(roots.left.right)
print(roots.left.val)
print(roots.left.left.val)
# Out:
# True
# 5
# None
# 3
# 3

# %%
roots = TreeNode(5)
roots.left = TreeNode(3)
roots.left.left = TreeNode(3)
roots.left.left.left = TreeNode(3)
roots.right = TreeNode(8)
roots.right.left = TreeNode(7)
roots.right.right = TreeNode(10)
roots.right.left.left = TreeNode(6) 
Solution().delete(roots,3)
print(roots.val==5 and roots.left==None and roots.right.val==8)
print(roots.val)
print(roots.right.val)
print(roots.left)
print(roots.left)

# %% [markdown]
# delete真的花了很久很久的時間終於完成了
#
# 接著先合併所有的BST code

# %%
class TreeNode(object):
    def __init__(self, x):
        self.val = x
        self.left = None
        self.right = None

class Solution(object):
    def insert(self, root, val):
        self.root = root
        self.val = val
        if root == None: #如果root原本沒有東西的話，新的節點即為root
            root = TreeNode(val)
        elif val <= root.val: #如果val的值小於root的值，放左邊，並討論左邊如果沒有值以及有值的時候
            if root.left != None:
                return self.insert(root.left, val)
            else:
                root.left = TreeNode(val)
                return root.left
        elif val > root.val: #如果val的值大於root的值，放右邊，並討論左邊如果沒有值以及有值的時候
            if root.right != None:
                return self.insert(root.right, val)
            else:
                root.right = TreeNode(val)
                return root.right
            
    def find(self, parent, root, target): #find放了3個參數
        if root == None: #如果root是空的，那就會find不到，找不到直接回傳None
            return None, None
        elif root != None: #如果root不是空的，分成幾種情況
            if root.val == target: #如果root等於要找的target
                return (parent, root) #回傳parent和root本身，因為有設三個變數，須把parent也return
            elif root.val > target: #如果root大於target
                return self.find(root, root.left, target) #把root當成parent，並繼續往左邊找
            elif root.val < target: #如果root小於target
                return self.find(root, root.right, target) #跟大於一樣，只是如果是小於，要往右邊找
    
    def del_min(self, node): #刪掉最小值
        if node.left==None: #如果進來節點的左邊沒有值，代表沒有最小值
            return node.val, node.right #直接回傳此節點值和右邊較大的點
        else: #剩下是如果進來節點的左邊有值
            val, node.left = self.del_min(node.left) #就看node.left.left是否有值，再跑del_min
            #會變成如果node.left.left空就回傳node.left.val,node.left.right
            return val, node
    
    def delete(self, root, target):
        while self.find(None, root, target) != (None, None):
            parent, node = self.find(None, root, target) #先用find找到node還有其parent
            if node.left == None or node.right == None: #有左或右一個child
                if parent != None: #如果節點也有parent
                    if parent.left == node: #如果此節點在parent的左邊
                        if node.left:
                            parent.left = node.left
                        if node.right:
                            parent.left = node.right
                        # 如果節點存在的子節點是在左，那就把左子節點接到parent的左邊
                        # 反之，存在的子節點是右，也是直接接到parent的左邊，那麼原本的node就會被取代掉
                    elif parent.right == node: #如果此節點在parent的右邊
                        if node.left:
                            parent.right = node.left
                        if node.right:
                            parent.right = node.right
                        #與上面相同道理，只是把node設在parent的右子節點
            else:
                right_min, node.right = self.del_min(node.right) #
                node.val = right_min
                
    def search(self, root, target):
        self.root = root
        self.target = target
        if not root: #如果root不存在，表示search不到，直接回傳None
            return None
        elif root.val == target: #如果root與target相等，search可直接回傳root值
            return root
        elif root.val < target: #如果root比target小(target比root大)，要繼續往右search
            return self.search(root.right, target)
        elif root.val > target: #如果root比target大(target比root小)，要繼續往左search
            return self.search(root.left, target)

# %%
root = TreeNode(5)
root.left = TreeNode(3)
root.left.left = TreeNode(3)
root.left.left.left = TreeNode(-5)
root.right = TreeNode(8)
root.right.left = TreeNode(7)
root.right.right = TreeNode(10)
root.right.left.left = TreeNode(6) 
print(Solution().insert(root,4) == root.left.right)
print(Solution().insert(root,-6) == root.left.left.left.left)
print(Solution().insert(root,12) == root.right.right.right)
print(Solution().insert(root,9) == root.right.right.left)
print(Solution().search(root,10)==root.right.right)
print(Solution().search(root,3)==root.left)
print(Solution().search(root,-5)==root.left.left.left)
print(Solution().search(root,8)==root.right)
print(Solution().search(root,7)==root.right.left)
print(Solution().search(root,6)==root.right.left.left)
# Out:
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True

# %%
root = TreeNode(5)
root.left = TreeNode(3)
root.left.left = TreeNode(3)
root.left.left.left = TreeNode(-5)
root.right = TreeNode(8)
root.right.left = TreeNode(7)
root.right.right = TreeNode(10)
root.right.left.left = TreeNode(6) 
Solution().delete(root,3)
print(root.val==5 and root.left.right==None and root.left.val==-5 and root.left.left==None)
# Out:
# True

# %% [markdown]
# # MODIFY

# %%
class TreeNode(object):
    def __init__(self, x):
        self.val = x
        self.left = None
        self.right = None
        
class Solution(object):    
    def modify(self, root, target, new_val):
        self.root = root
        self.target = target
        self.new_val = new_val
        return True

# %%
root = TreeNode(5)
root.left = TreeNode(3)
root.left.left = TreeNode(3)
root.left.left.left = TreeNode(-5)
root.right = TreeNode(8)
root.right.left = TreeNode(7)
root.right.right = TreeNode(10)
root.right.left.left = TreeNode(6) 
Solution().modify(root,3,4)
print(root.left.val==4 and root.left.left.val==4)
# Out:
# False

# %%
class TreeNode(object):
    def __init__(self, x):
        self.val = x
        self.left = None
        self.right = None
        
class Solution(object):    
    def modify(self, root, target, new_val):
        self.root = root
        self.target = target
        self.new_val = new_val
        if root != None: #如果root有值
            if root.val == target: #如果root的值和target相等
                root.val = new_val #那麼root改成新的數new_val
        if root.right != None: #如果root有right子節點
            self.modify(root.right, target, new_val) #把root.right當成root再跑一次
        if root.left != None: #如果root有left子節點
            self.modify(root.left, target, new_val) #把root.left當成root再跑一次
        return root

# %%
root = TreeNode(5)
root.left = TreeNode(3)
root.left.left = TreeNode(3)
root.left.left.left = TreeNode(-5)
root.right = TreeNode(8)
root.right.left = TreeNode(7)
root.right.right = TreeNode(10)
root.right.left.left = TreeNode(6) 
Solution().modify(root,3,4)
print(root.left.val==4 and root.left.val==4)
# Out:
# True

# %% [markdown]
# 最後再次合併所有的code

# %%
class TreeNode(object):
    def __init__(self, x):
        self.val = x
        self.left = None
        self.right = None

class Solution(object):
    def insert(self, root, val):
        self.root = root
        self.val = val
        if root == None: #如果root原本沒有東西的話，新的節點即為root
            root = TreeNode(val)
        elif val <= root.val: #如果val的值小於root的值，放左邊，並討論左邊如果沒有值以及有值的時候
            if root.left != None:
                return self.insert(root.left, val)
            else:
                root.left = TreeNode(val)
                return root.left
        elif val > root.val: #如果val的值大於root的值，放右邊，並討論左邊如果沒有值以及有值的時候
            if root.right != None:
                return self.insert(root.right, val)
            else:
                root.right = TreeNode(val)
                return root.right
            
    def find(self, parent, root, target): #find放了3個參數
        if root == None: #如果root是空的，那就會find不到，找不到直接回傳None
            return None, None
        elif root != None: #如果root不是空的，分成幾種情況
            if root.val == target: #如果root等於要找的target
                return (parent, root) #回傳parent和root本身，因為有設三個變數，須把parent也return
            elif root.val > target: #如果root大於target
                return self.find(root, root.left, target) #把root當成parent，並繼續往左邊找
            elif root.val < target: #如果root小於target
                return self.find(root, root.right, target) #跟大於一樣，只是如果是小於，要往右邊找
    
    def del_min(self, node): #刪掉最小值
        if node.left==None: #如果進來節點的左邊沒有值，代表沒有最小值
            return node.val, node.right #直接回傳此節點值和右邊較大的點
        else: #剩下是如果進來節點的左邊有值
            val, node.left = self.del_min(node.left) #就看node.left.left是否有值，再跑del_min
            #會變成如果node.left.left空就回傳node.left.val,node.left.right
            return val, node
    
    def delete(self, root, target):
        while self.find(None, root, target) != (None, None):
            parent, node = self.find(None, root, target) #先用find找到node還有其parent
            if node.left == None or node.right == None: #有左或右一個child
                if parent != None: #如果節點也有parent
                    if parent.left == node: #如果此節點在parent的左邊
                        if node.left:
                            parent.left = node.left
                        if node.right:
                            parent.left = node.right
                        # 如果節點存在的子節點是在左，那就把左子節點接到parent的左邊
                        # 反之，存在的子節點是右，也是直接接到parent的左邊，那麼原本的node就會被取代掉
                    elif parent.right == node: #如果此節點在parent的右邊
                        if node.left:
                            parent.right = node.left
                        if node.right:
                            parent.right = node.right
                        #與上面相同道理，只是把node設在parent的右子節點
            else:
                right_min, node.right = self.del_min(node.right) #
                node.val = right_min
                
    def search(self, root, target):
        self.root = root
        self.target = target
        if not root: #如果root不存在，表示search不到，直接回傳None
            return None
        elif root.val == target: #如果root與target相等，search可直接回傳root值
            return root
        elif root.val < target: #如果root比target小(target比root大)，要繼續往右search
            return self.search(root.right, target)
        elif root.val > target: #如果root比target大(target比root小)，要繼續往左search
            return self.search(root.left, target)
        
    def modify(self, root, target, new_val):
        pass

# %% [markdown]
# 歷經了兩個禮拜的折磨，終於完成了第三次作業@@
