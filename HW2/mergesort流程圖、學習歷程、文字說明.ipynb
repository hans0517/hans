# %% [markdown]
# # MergeSort
# * 一開始的個人理解
#   * 1.最初先將數列分成兩半
#   * 2.再一直分到剩兩個兩個一組，如果總數為奇數，則剩的數自己一組
#   * 3.兩個兩個比大小，小的放左，大的放右
#   * 4.合併後比較，'依序'比較
#   * 5.比到最後完成排序
#
#   * 參考資料:
#     * Pseudocode : https://www.slideshare.net/MJabin/merge-sort-and-quick-sort
#     * GeeksforGeeks : https://www.geeksforgeeks.org/merge-sort/
#     * https://runestone.academy/runestone/books/published/pythonds/SortSearch/TheMergeSort.html

# %%
from IPython.display import Image
from IPython.core.display import HTML

# %%
Image(filename = "D:\三上-資料結構與演算法\MergeSortpic.jpg", width=750, height=500)

# %%
Image(filename = "D:\三上-資料結構與演算法\S__45072408.jpg", width=750, height=400)

# %%
class Solution(object):
    def merge_sort(self, nums):
        middle = len(nums)//2
        left = nums[:middle]
        right = nums[middle:]
        self.merge_sort(left)
        self.merge_sort(right)
        
        i = j = k = 0
        for k in range(0, len(nums)):
            if left[i] <= right[j]:
                nums[k] = left[i]
                i+=1
            else:
                nums[k] = right[j]
                j+=1

# %%
nums = [-2, 6, 7, -4, 0, 3, -1, 4]

# %%
merge_sort(nums)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-42774883b04a> in <module>
# ----> 1 merge_sort(nums)
#
# NameError: name 'merge_sort' is not defined

# %%
Ans = Solution()

# %%
Ans.merge_sort(nums)
# Out:
# ---------------------------------------------------------------------------
# RecursionError                            Traceback (most recent call last)
# <ipython-input-10-914c0ad1a9a5> in <module>
# ----> 1 Ans.merge_sort(nums)
#
# <ipython-input-3-4c8493ad54c7> in merge_sort(self, nums)
#       4         left = nums[:middle]
#       5         right = nums[middle:]
# ----> 6         self.merge_sort(left)
#       7         self.merge_sort(right)
#       8
#
# ... last 1 frames repeated, from the frame below ...
#
# <ipython-input-3-4c8493ad54c7> in merge_sort(self, nums)
#       4         left = nums[:middle]
#       5         right = nums[middle:]
# ----> 6         self.merge_sort(left)
#       7         self.merge_sort(right)
#       8
#
# RecursionError: maximum recursion depth exceeded while calling a Python object

# %% [markdown]
# 翻譯了一下意思...這邊的錯誤是超出最大遞歸深度
#
# 參考了 : https://www.itread01.com/p/444115.html

# %%
import sys

# %%
sys.getrecursionlimit()
# Out:
# 3000

# %%
sys.setrecursionlimit(3000)

# %% [markdown]
# 上網找了此類的解決辦法，好像還是沒辦法解決@@

# %%
class Solution(object):
    def merge_sort(self, nums):
        merge1(nums, first, last)

# %%
def merge1(nums, first, last):
    if first < last:
            middle = len(nums)//2
            merge1(nums, fisrt, middle)
            merge1(nums, middle+1, last)
            merge2(nums, first, middle, last)

# %%
def merge2(nums, first, middle, last):
    left = nums[:middle]
    right = nums[middle:]
    i = j = k = 0
    for k in range(0, len(nums)):
        if left[i] <= right[j]:
            nums[k] = left[i]
            i+=1
        else:
            nums[k] = right[j]
            j+=1

# %%
nums = [-2, 6, 7, -4, 0, 3, -1, 4]

# %%
Ans = Solution()

# %%
Ans.merge_sort(nums)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-26-914c0ad1a9a5> in <module>
# ----> 1 Ans.merge_sort(nums)
#
# <ipython-input-17-9c9a399024a7> in merge_sort(self, nums)
#       1 class Solution(object):
#       2     def merge_sort(self, nums):
# ----> 3         merge1(nums, first, last)
#       4         if first < last:
#       5             middle = len(nums)//2
#
# NameError: name 'first' is not defined

# %%
class Solution(object):
    def merge_sort(self, nums):
        merge1(nums, first, last)
        first = nums[0]
        last = nums[len(nums)]

# %%
def merge1(nums, first, last):
    if first < last:
        middle = len(nums)//2
        merge1(nums, fisrt, middle)
        merge1(nums, middle+1, last)
        merge2(nums, first, middle, last)

# %%
def merge2(nums, first, middle, last):
    left = nums[:middle]
    right = nums[middle:]
    i = j = k = 0
    for k in range(0, len(nums)):
        if left[i] <= right[j]:
            nums[k] = left[i]
            i+=1
        else:
            nums[k] = right[j]
            j+=1

# %%
nums = [-2, 6, 7, -4, 0, 3, -1, 4]

# %%
Ans = Solution()

# %%
Ans.merge_sort(nums)
# Out:
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# <ipython-input-39-914c0ad1a9a5> in <module>
# ----> 1 Ans.merge_sort(nums)
#
# <ipython-input-34-fc9a44c31e48> in merge_sort(self, nums)
#       1 class Solution(object):
#       2     def merge_sort(self, nums):
# ----> 3         merge1(nums, first, last)
#       4         first = nums[0]
#       5         last = nums[len(nums)]
#
# UnboundLocalError: local variable 'first' referenced before assignment

# %% [markdown]
# 前面完全沒搞懂狀況哈哈哈哈哈
#
# 在class裡，def不能分開定義，要把所有都包在class裡
#
# 於是把所有code合併在一起試試看囉~~~

# %%
class Solution(object):
    def merge_sort(self, nums):
        self.merge1(nums, 0, len(nums)-1)
    def merge1(self, nums, first, last):
        if first < last:
            middle = len(nums)//2
            self.merge1(nums, first, middle)
            self.merge1(nums, middle+1, last)
            self.merge2(nums, first, middle, last)
    def merge2(self, nums, first, middle, last):
        left = nums[first:middle]
        right = nums[middle:last]
        i = j = k = 0
        for k in range (first, last+1):
            if left[i] <= right[j]:
                nums[k] = left[i]
                i+=1
            else:
                nums[k] = right[j]
                j+=1
            return nums[k]

# %%
nums = [-2, 6, 7, -4, 0, 3, -1, 4]

# %%
Ans = Solution()

# %%
Ans.merge_sort(nums)
# Out:
# ---------------------------------------------------------------------------
# RecursionError                            Traceback (most recent call last)
# <ipython-input-34-914c0ad1a9a5> in <module>
# ----> 1 Ans.merge_sort(nums)
#
# <ipython-input-31-769046f8ccf1> in merge_sort(self, nums)
#       1 class Solution(object):
#       2     def merge_sort(self, nums):
# ----> 3         self.merge1(nums, 0, len(nums)-1)
#       4     def merge1(self, nums, first, last):
#       5         if first < last:
#
# <ipython-input-31-769046f8ccf1> in merge1(self, nums, first, last)
#       5         if first < last:
#       6             middle = len(nums)//2
# ----> 7             self.merge1(nums, first, middle)
#       8             self.merge1(nums, middle+1, last)
#       9             self.merge2(nums, first, middle, last)
#
# ... last 1 frames repeated, from the frame below ...
#
# <ipython-input-31-769046f8ccf1> in merge1(self, nums, first, last)
#       5         if first < last:
#       6             middle = len(nums)//2
# ----> 7             self.merge1(nums, first, middle)
#       8             self.merge1(nums, middle+1, last)
#       9             self.merge2(nums, first, middle, last)
#
# RecursionError: maximum recursion depth exceeded in comparison

# %% [markdown]
# 好煩歐，又遇到到一樣的問題了QQ尋求高手教導，原來是因為沒有設定限制，所以進入無限迴圈。
#
# 試試看設定限制，在merge的地方加上len(nums)<2就回傳，避免沒有限制造成無限迴圈。

# %%
class Solution(object):
    def merge_sort(self, nums):
        if len(nums)<2:
            return nums
        self.merge1(nums, 0, len(nums)-1)
    def merge1(self, nums, first, last):
        if first < last:
            middle = len(nums)//2
            self.merge1(nums, first, middle)
            self.merge1(nums, middle+1, last)
            self.merge2(nums, first, middle, last)
    def merge2(self, nums, first, middle, last):
        left = nums[first:middle]
        right = nums[middle:last]
        i = j = k = 0
        for k in range (first, last+1):
            if left[i] <= right[j]:
                nums[k] = left[i]
                i+=1
            else:
                nums[k] = right[j]
                j+=1
            return nums

# %%
nums = [-2, 6, 7, -4, 0, 3, -1, 4]

# %%
Ans = Solution()

# %%
Ans.merge_sort(nums)
# Out:
# ---------------------------------------------------------------------------
# RecursionError                            Traceback (most recent call last)
# <ipython-input-629-914c0ad1a9a5> in <module>
# ----> 1 Ans.merge_sort(nums)
#
# <ipython-input-626-bc338523c514> in merge_sort(self, nums)
#       3         if len(nums)<2:
#       4             return nums
# ----> 5         self.merge1(nums, 0, len(nums)-1)
#       6     def merge1(self, nums, first, last):
#       7         if first < last:
#
# <ipython-input-626-bc338523c514> in merge1(self, nums, first, last)
#       7         if first < last:
#       8             middle = len(nums)//2
# ----> 9             self.merge1(nums, first, middle)
#      10             self.merge1(nums, middle+1, last)
#      11             self.merge2(nums, first, middle, last)
#
# ... last 1 frames repeated, from the frame below ...
#
# <ipython-input-626-bc338523c514> in merge1(self, nums, first, last)
#       7         if first < last:
#       8             middle = len(nums)//2
# ----> 9             self.merge1(nums, first, middle)
#      10             self.merge1(nums, middle+1, last)
#      11             self.merge2(nums, first, middle, last)
#
# RecursionError: maximum recursion depth exceeded in comparison

# %% [markdown]
# 以上 : middle=len(nums)//2，但是nums都是一樣的，所以每一次都做一樣的事，可以切，只傳入那部分的array，他的middle就會收斂，才不會無限迴圈。

# %%
class Solution(object):
    def merge_sort(self, nums):
        self.nums = nums
        if len(nums)<2:
            return nums
        self.merge1(nums, 0, len(nums)-1)
        self.merge1(nums, first, middle)
        self.merge1(nums, middle+1, last)
    def merge1(self, array, first, last):
        if first < last:
            middle = len(array)//2
            left = array[first:middle]
            right = array[middle:last]
            
            i = j = k = 0
            for k in range (first, last+1):
                if left[i] <= right[j]:
                    nums[k] = left[i]
                    i+=1
                else:
                    nums[k] = right[j]
                    j+=1
                k+=1
            return nums[k]

# %%
nums = [-2, 6, 7, -4, 0, 3, -1, 4]

# %%
Ans = Solution()

# %%
Ans.merge_sort(nums)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-582-914c0ad1a9a5> in <module>
# ----> 1 Ans.merge_sort(nums)
#
# <ipython-input-579-6fe694f76bf3> in merge_sort(self, nums)
#       4         if len(nums)<2:
#       5             return nums
# ----> 6         self.merge1(nums, 0, len(nums)-1)
#       7         self.merge1(nums, first, middle)
#       8         self.merge1(nums, middle+1, last)
#
# <ipython-input-579-6fe694f76bf3> in merge1(self, array, first, last)
#      15             i = j = k = 0
#      16             for k in range (first, last+1):
# ---> 17                 if left[i] <= right[j]:
#      18                     nums[k] = left[i]
#      19                     i+=1
#
# IndexError: list index out of range

# %%
class Solution(object):
    def merge_sort(self, nums):
        self.nums = nums
        if len(nums)<2:
            return nums
        else:
            self.merge1(nums, 0, len(nums)-1)
    def merge1(self, nums, first, last):
        print(nums, first, last)
        
        if first < last:
            middle = len(nums)//2
            left = nums[first:middle]
            right = nums[middle:last]
            left = self.merge1(left, first, middle)
            right = self.merge1(right, middle+1, last)

        i = j = k = 0
        while i < len(left) and j < len(right):
            if left[i] < right[j]:
                nums[k]=left[i]
                i=i+1
            else:
                nums[k]=right[j]
                j=j+1
            k=k+1
        while i < len(left):
            nums[k]=left[i]
            i=i+1
            k=k+1

        while j < len(right):
            nums[k]=right[j]
            j=j+1
            k=k+1

# %%
nums = [-2, 6, 7, -4, 0, 3, -1, 4]

# %%
Ans = Solution()

# %%
Ans.merge_sort(nums)
# Out:
# [-2, 6, 7, -4, 0, 3, -1, 4] 0 7
# [-2, 6, 7, -4] 0 4
# [-2, 6] 0 2
# [-2] 0 1
# [] 0 0
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# <ipython-input-365-914c0ad1a9a5> in <module>
# ----> 1 Ans.merge_sort(nums)
#
# <ipython-input-362-e57c7d4bf32c> in merge_sort(self, nums)
#       5             return nums
#       6         else:
# ----> 7             self.merge1(nums, 0, len(nums)-1)
#       8     def merge1(self, nums, first, last):
#       9         print(nums, first, last)
#
# <ipython-input-362-e57c7d4bf32c> in merge1(self, nums, first, last)
#      13             left = nums[first:middle]
#      14             right = nums[middle:last]
# ---> 15             left = self.merge1(left, first, middle)
#      16             right = self.merge1(right, middle+1, last)
#      17
#
# <ipython-input-362-e57c7d4bf32c> in merge1(self, nums, first, last)
#      13             left = nums[first:middle]
#      14             right = nums[middle:last]
# ---> 15             left = self.merge1(left, first, middle)
#      16             right = self.merge1(right, middle+1, last)
#      17
#
# <ipython-input-362-e57c7d4bf32c> in merge1(self, nums, first, last)
#      13             left = nums[first:middle]
#      14             right = nums[middle:last]
# ---> 15             left = self.merge1(left, first, middle)
#      16             right = self.merge1(right, middle+1, last)
#      17
#
# <ipython-input-362-e57c7d4bf32c> in merge1(self, nums, first, last)
#      13             left = nums[first:middle]
#      14             right = nums[middle:last]
# ---> 15             left = self.merge1(left, first, middle)
#      16             right = self.merge1(right, middle+1, last)
#      17
#
# <ipython-input-362-e57c7d4bf32c> in merge1(self, nums, first, last)
#      17
#      18         i = j = k = 0
# ---> 19         while i < len(left) and j < len(right):
#      20             if left[i] < right[j]:
#      21                 nums[k]=left[i]
#
# UnboundLocalError: local variable 'left' referenced before assignment

# %%
def merge_sort(nums):
    if len(nums)<2:
        return nums
        merge1(nums, 0, len(nums)-1)
def merge1(nums, first, last):
    if first < last:
        print(nums, first, last)
        middle = len(nums)//2
        left = nums[first:middle]
        right = nums[middle:last]
        merge1(left, first, middle)
        merge1(right, middle+1, last)

    i = j = k = 0
    while i < len(left) and j < len(right):
        if left[i] < right[j]:
            nums[k]=left[i]
            i=i+1
        else:
            nums[k]=right[j]
            j=j+1
        k=k+1
    while i < len(left):
        nums[k]=left[i]
        i=i+1
        k=k+1

    while j < len(right):
        nums[k]=right[j]
        j=j+1
        k=k+1
    return nums[k]

# %%
nums = [-2, 6, 7, -4, 0, 3, -1, 4]

# %%
merge_sort(nums)

# %%
print(nums)
# Out:
# [-2, 6, 7, -4, 0, 3, -1, 4]

# %% [markdown]
# 問題到底在哪@@好像設太多變數，把自己弄得太複雜........

# %%
def merge_sort(nums):
    if len(nums)<2: #設定限制，以防進入無限迴圈
        return nums
    else:
        middle = len(nums)//2
        left = nums[:middle]
        right = nums[middle:] #依照middle，把nums切成兩半
        merge_sort(left)
        merge_sort(right)

        i = j = k = 0
        while i < len(left) and j < len(right):
            if left[i] < right[j]:
                nums[k] = left[i]
                i = i+1 #如果左邊的數小於右邊的，將左邊的數加到空的nums的k
            else:
                nums[k] = right[j]
                j = j+1 #跟以上同邏輯，右邊的加進去
            k = k+1 #k要跟著移動，加完一個要繼續到下一個位置
        while i < len(left):
            nums[k] = left[i]
            i = i+1
            k = k+1

        while j < len(right):
            nums[k] = right[j]
            j = j+1
            k = k+1

# %%
nums = [-2, 6, 7, -4, 0, 3, -1, 4]

# %%
merge_sort(nums)

# %%
print(nums)
# Out:
# [-4, -2, -1, 0, 3, 4, 6, 7]

# %% [markdown]
# ### 轉換成助教要求的格式

# %%
class Solution(object):
    def merge_sort(self, nums):
        if len(nums)<2: #設定限制，以防進入無限迴圈
            return nums
        else:
            middle = len(nums)//2
            left = nums[:middle]
            right = nums[middle:] #依照middle，把nums切成兩半
            self.merge_sort(left)
            self.merge_sort(right)
            
            i = j = k = 0
            while i < len(left) and j < len(right):
                if left[i] < right[j]:
                    nums[k] = left[i]
                    i = i+1 #如果左邊的數小於右邊的，將左邊的數加到空的nums的k
                else:
                    nums[k] = right[j]
                    j = j+1 #跟以上同邏輯，右邊的加進去
                k = k+1 #k要跟著移動，加完一個要繼續到下一個位置
            while i < len(left):
                nums[k] = left[i]
                i = i+1
                k = k+1

            while j < len(right):
                nums[k] = right[j]
                j = j+1
                k = k+1
            return nums

# %%
nums = [-2, 6, 7, -4, 0, 3, -1, 4]

# %%
Solution().merge_sort(nums)
# Out:
# [-4, -2, -1, 0, 3, 4, 6, 7]

# %% [markdown]
# MergeSort感想:
#
# 基礎不好真的要花上三天三夜不斷地去找資料，或是找一些基本的用法，還要不斷地去打擾一些高手同學，繼續一試再試，
#
# 耗時耗精力、改到換瘋掉還一直Error真的很想死...
#
# 努力理解邏輯，看懂Error在Error甚麼意思的
#
# 歷經了In[624] 終於完成了第二次作業的一小部分QQ認命繼續去做HeapSort吧 88
